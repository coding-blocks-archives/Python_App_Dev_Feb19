# %%
import requests

# %%
a = b'aa'

# %%
print(a.decode('utf-8'))
# Out:
# aa

# %%
url = "http://www.google.com"

# %%
r = requests.get(url)

# %%
a = r.content

# %%
r.headers
# Out:
# {'Date': 'Sat, 09 Mar 2019 06:26:12 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'Content-Length': '5312', 'X-XSS-Protection': '1; mode=block', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2019-03-09-06; expires=Mon, 08-Apr-2019 06:26:12 GMT; path=/; domain=.google.com, NID=162=nLOSHHFNMuJTXiXDj-zER6VY8M9tOL86BivpzZFdYB1v3hoBopMjO7a_WzG4tBNg3JGnqa6Vx9_Kn2_0IrBgnpU6PW-bt2PRAH-MXZR-ggSfGHnDN6JD8939HdCrTERYOPcWcPxcB5uwGM43UqTikce1e6Nhn8GOGdhE4OxyRrY; expires=Sun, 08-Sep-2019 06:26:12 GMT; path=/; domain=.google.com; HttpOnly'}

# %%
a.decode('ISO-8859-1')
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8" />\n\t\t\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n    \t\t<link rel="icon" type="image/x-icon" href="images/favicon.png" />\n    \t\t<script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>\n\t\t\t<link rel="stylesheet" href="css/jquery.modal.min.css" type="text/css" media="screen" />\n\t    <title>Abacus Classes | Vedic Maths | Study Abacus | Teacher Training | Abacus Franchise</title>\n\n\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"","ext":".png","source":{"concatemoji":"js\\/wp-emoji-release.min.js?ver=4.2.4"}};\n\t\t\t!function(a,b,c){function d(a){var c=b.createElement("canvas"),d=c.getContext&&c.getContext("2d");return d&&d.fillText?(d.textBaseline="top",d.font="600 32px Arial","flag"===a?(d.fillText(String.fromCharCode(55356,56812,55356,56807),0,0),c.toDataURL().length>3e3):(d.fillText(String
# ...
